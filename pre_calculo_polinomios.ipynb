# %% [markdown]
# <h1>
#     <b>
#         <font color='#660000'>
#             Minicurso: A linguagem Python e conceitos do Pré-Cálculo - TEMAT
#         </font>
#     </b>
# </h1>

# %% [markdown]
# ## 1. Introdução ao Python
#
# Python é uma linguagem de programação de alto nível, interpretada e de propósito geral. É conhecida por sua sintaxe simples e legível, o que a torna uma excelente escolha para iniciantes em programação.

# %% [markdown]
# ### 1.1 Conceitos Iniciais
#
# O Python popularizou-se nos últimos anos por ser uma linguagem de programação de código aberto, de fácil leitura e possuir módulos terceirizados (chamados de bibliotecas) desenvolvidas pela comunidade que permitem trabalhar em diferentes áreas.

# %% [markdown]
# ### 1.2 Algoritmo
#
# O termo algoritmo é amplamente associado à computação. Vejamos algumas definições de algoritmo:
#
# 1. Um procedimento passo a passo para a solução de um problema.
# 2. Uma sequência **ordenada** e detalhada de ações a serem executadas para realizar alguma tarefa.

# %% [markdown]
# ### 1.3 Declaração de Variáveis
#
# A declaração de variáveis ocorre ao atribuir um valor utilizando o operador de atribuição **=**. Nesse processo, o nome da variável (identificador) é seguido pelo operador de atribuição e, em seguida, pelo valor que será atribuído à variável.

# %% [markdown]
# <center>
#
# ![kll.png](data:image/png;base64,...)

# %% [markdown]
# <h4>
#     <b>
#         <font color='#008800"'>Exemplo 1</font>
#     </b>
# </h4>
# Faça o que se pede:<br>
# <b>a)</b> Declare uma variável numérica, com identificador <b>a</b>, atribuindo-lhe o valor <b>10</b>. Para executar o código, pressione <b>Shift</b> + <b>Enter</b>.

# %%
a= 10
a
# Out:
# 10

# %% [markdown]
# <b>b)</b> Declare duas variáveis numéricas, com identificadores <b>a</b> e <b>b</b>, atribuindo-lhe o valores <b>25</b> e <b>55</b>. Para executar o código, pressione <b>Shift</b> + <b>Enter</b>.

# %%
a = 25

b = 55
a+b
# Out:
# 80

# %% [markdown]
# <b>c)  <font color='#BD2A2A'>(Exercício)</font></b> Declare uma variável numérica, com identificador <b>c</b>, atribuindo-lhe o valor <b>194</b>.

# %%
a=94
b=100
a+b
# Out:
# 194

# %% [markdown]
# <center>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <b>b)</b>
# $ 2+\frac{2}{2\cdot 4^2} - 2 $

# %%
2+(2/(2*4**2))-2
# Out:
# 0.0625

# %% [markdown]
# <b>c) <font color='#BD2A2A'>(Exercício)</font></b>
# $ 2+\frac{2}{2} \cdot (4^2 - 2) $

# %%
2+2/2*(4**2-2)
# Out:
# 16.0

# %%
from sympy import *

# %% [markdown]
# <center>
#
#
# ![uyuyuyu.png](data:image/png;base64,...)

# %% [markdown]
# <h3><b>2. 2 Variáveis simbólicas
#     </b>
# </h3>
#
# &nbsp; Para declarar <b>uma</b> variável simbólica, podemos utilizar a função <b>Symbol</b>.
#
# <center><hr><b>
#
# ```python
# identificador = Symbol('símbolo')
# ```
#
# </b></center><hr>
#
# <h4>
#     <b>
#         <font color='#008800"'>Exemplo 4</font>
#     </b>
# </h4>
# &nbsp; Declare uma variável simbólica $x$.

# %%
x = Symbol("x")
x
# Out:
# x

# %% [markdown]
# <h3><b>2. 3 Função no Python
#     </b>
# </h3>
#
# Uma função no Python é um bloco de código independente que pode ser executado várias vezes em um programa. Ela pode receber entradas (parâmetros), processar dados e retornar uma saída.
#
# A estrutura básica de uma função é a seguinte:
#
#
#
# *   **def**: Palavra-chave que indica a definição de uma função.
# *   **nome_da_funcao**: Nome descritivo que indica o que a função faz.
# *   **paramos**: Valores que a função recebe para processar (opcional).
# *   **return**: Palavra-chave que indica o valor que a função devolve após sua execução (opcional).
#
#
# Como no exemplo:
#
# <center><hr><b>
#
# ```python
# def nome_da_funcao(parametros):
#     instrução 1
#     instrução 2
#     ...
#     return valor (opcional)
# ```
#
# </b></center><hr>

# %% [markdown]
# Para utilizar como as funções matemáticas pode ser utilizado da seguinte maneira:
#
# <center><hr><b>
#
# ```python
# def f(x):
#     return 2*x
# ```
#
# </b></center><hr>
#
# Onde f é o nome da função x os parâmetros e o que é retornado o valor da função quando o parâmetro é x.

# %% [markdown]
# <h4>
#     <b>
#         <font color='#008800"'>Exemplo 5</font>
#     </b>
# </h4>
# &nbsp; Declare uma função $2x$ utilizando o def.

# %%
def f(x):
    return 2*x

# %% [markdown]
# <h3><b>2. 4 Valor de uma função em um ponto
#     </b>
# </h3>
# &nbsp; Para determinar o valor de uma função em um ponto da maneira que foi estipulado basta escrever:
# <center><hr><b>
#
# ```python
# f(ponto)
# ```
#
# </b></center><hr>
#
# <h4>
#     <b>
#         <font color='#008800"'>Exemplo 6</font>
#     </b>
# </h4>
#
# &nbsp; Utilize a função $f$ declarada no <font color='#008800'><b>Exemplo 5</b></font> e faça o que se pede nos itens a seguir:
#
# <b>a)</b> Calcule o valor de $f(x)$ em $x=1$.

# %%
f(1)#substitui x por 1
# Out:
# 2

# %% [markdown]
# <b>b) <font color='#BD2A2A'>(Exercício)</font></b>  Calcule o valor de $f(x)$ em $x=20$.

# %%
f(20)
# Out:
# 40

# %% [markdown]
# <h3><b>2. 5 Representação gráfica de funções de uma variável
#     </b>
# </h3>
#
# &nbsp; A função <b>plot</b> é utilizada para representar graficamente funções de uma variável. Se <b>f</b> é a lei de uma função expressa em termos de uma variável simbólica <b>x</b>, a representação gráfica no intervalo <b>[a,b]</b> pode ser feita através da linha de comando:
# <center><hr><b>
#
# ```python
# plot(f,(x,a,b))
# ```
#
# </b></center><hr>
#
# <h4>
#     <b>
#         <font color='#008800"'>Exemplo 7</font>
#     </b>
# </h4>
#
# &nbsp; Represente graficamente a função $f(x)$ do <font color='#008800'><b>Exemplo 5</b></font> utilizando o comando <b>plot</b>.

# %%
plot(f,(x,-10,10))

# %% [markdown]
# <h2><b>Problema 1: </b>
#
# &nbsp;Uma empresa produz e vende determinado tipo de produto. A quantidade que ela consegue vender varia conforme o preço, da seguinte forma: a um preço $y$ ela consegue vender $x$ unidades do produto, de acordo com a equação:
# <h3>
# $$
# y = 50 - \frac{x}{2}
# $$
#
# <b >Baseado em:</b> Menezes, Maria Fernanda R.. <b>Problemas envolvendo modelagem de funções polinomiais, racionais e circulares</b>

# %% [markdown]
# <h3>a) Usando Python, defina a função preço.

# %% [markdown]
# <h3>b) Calcule o preço de 20 unidades do produto.

# %%
p= Symbol("p")
def q (p):
  return 50-(2*p/3)

# %%
q (20)
# Out:
# 36.666666666666664

# %% [markdown]
# <h3>c) Plote o gráfico, e analise se podemos afirmar que quanto maior o número de unidades do produto, maior o preço.

# %%
plot(q,(x,50,-50))

# %% [markdown]
# <h2><b>Problema 2: </b>
#
# &nbsp; O custo de transporte de uma certa carga por ferrovia é composta de uma quantidade fixa de $100$ reais mais $5$ reais por quilômetro rodado. A mesma carga transportada por rodovia tem um custo fixo de $60$ reais mais $6$ reais por quilômetro rodado.
# <h3>

# %% [markdown]
# <h3>a) Quanto será gasto por cada um se rodassem $100$km?

# %%
g= Symbol("g")
def f(g):
  return 100+5*g

y= Symbol("y")
def f(y):
  return 60+6*y

# %% [markdown]
# <h3>b) Utilizando o Python, plote um gráfico mostrando em cada caso a relação custo e quilômetro rodado. Estabeleça um critério de escolha de transporte por rodovia ou ferrovia considerando a distância a ser percorrida.

# %%
plot(g,(g,600,-600)); plot(y,(y,660,-660))

# %% [markdown]
# <h2><b>Problema 3: </b>
#
# &nbsp; Dois homens saem numa caminhada, do mesmo ponto, ao mesmo tempo. Um anda $2$ quilômetros por hora e o outro, $3$ quilômetros por hora.
# <h3>

# %% [markdown]
# <h3>a) Em 1h15min, quantos quilômetros cada um terá percorrido?

# %%
a= Symbol("a")
def f(a):
  return 2*a

b= Symbol("b")
def g(b):
  return 3*b

# %%
f(1.25), g(1.25)
# Out:
# (2.5, 3.75)

# %% [markdown]
# <h3> b) Plote o gráfico da posição deles em relação ao tempo.

# %%
plot((f,(a,0,2.5)),(g,(b,0,3.75)))

# %% [markdown]
# <h2><b>Problema 4: </b>
#
# &nbsp; Fazendo uma pesquisa sobre qual plano de celular contratar, descobriu-se que no plano 1 se pagava uma taxa inicial de R\$300,00 e depois se pagava R\$50,00 mensalmente e no plano 2 não havia taxa inicial, mas se pagava R\$80,00 mensais.
# <h3>

# %% [markdown]
# <h3>a) Quais são as funções que expressam o valor pago total em relação ao tempo dos planos?

# %%
a= Symbol("a")
def f(a):
   return 300+(50*a)

b= Symbol("b")
def g(b):
  return 80*b

# %% [markdown]
# <h3>b) Plote o gráfico e através dele analise quais dos planos se gasta menos para um tempo maior.

# %%
g(12), f(12)
# Out:
# (960, 900)

# %%
plot((f,(a,0,960)), (g,(b,0,900)))

# %% [markdown]
# <h2><b>Problema 5: </b>
#
# &nbsp; Estima-se que a população de uma certa comunidade será de $P(t) = 20- \frac{6}{t+1}$.
# <h3>

# %% [markdown]
# <h3>a) Expresse a função no Python e diga qual era a população inicial.

# %% [markdown]
# <h3>b) Daqui a 9 anos qual será a população da comunidade?

# %% [markdown]
# <h3>c) Pode-se afirmar que quanto mais o tempo passar mais aumenta a população?

# %% [markdown]
# <h3>d) Estude o crescimento da população fazendo o gráfico da função.
