# %% [markdown]
# <h1>
#     <b>
#         <font color='#660000'>
#             Oficina pré-cálculo com Python - Acolhida Cidadã Matemática Aplicada 2025
#         </font>
#     </b>
# </h1>
# <b >Baseado em:</b> Menezes, Maria Fernanda R.. <b>Problemas envolvendo modelagem de funções polinomiais, racionais e circulares</b>

# %% [markdown]
# ## 1. Introdução ao Python
#
# Python é uma linguagem de programação de alto nível, interpretada e de propósito geral. É conhecida por sua sintaxe simples e legível, o que a torna uma excelente escolha para iniciantes em programação.

# %% [markdown]
# ### 1.1 Variáveis e Tipos de Dados
#
# Em Python, podemos criar variáveis para armazenar diferentes tipos de dados. Vamos ver alguns exemplos:

# %% [markdown]
# ### 1.2 Operações Básicas em Python
#
# Python suporta várias operações matemáticas básicas. Vamos ver alguns exemplos:

# %% [markdown]
# ![kll.png](data:image/png;base64,...)

# %% [markdown]
# <h4>
#     <b>
#         <font color='#008800"'>Exemplo 1</font>
#     </b>
# </h4>
# Faça o que se pede:<br>
# <b>a)</b> Declare uma variável numérica, com identificador <b>a</b>, atribuindo-lhe o valor <b>2</b>. Para executar o código, pressione <b>Shift</b> + <b>Enter</b>.

# %%
# Out:
# oi 5

# %% [markdown]
# <b>b)</b> Declare duas variáveis numéricas, com identificadores <b>a</b> e <b>b</b>, atribuindo-lhe o valores <b>2</b> e <b>4</b>. Para executar o código, pressione <b>Shift</b> + <b>Enter</b>.

# %%
from sympy import *

# %% [markdown]
# <h3><b>2. 2 Variáveis simbólicas
#     </b>
# </h3>
#
# &nbsp; Para declarar <b>uma</b> variável simbólica, podemos utilizar a função <b>Symbol</b>.
#
# <center><hr><b>
#
# ```python
# identificador = Symbol('símbolo')
# ```
#
# </b></center><hr>
#
#
# &nbsp; Declare uma variável simbólica $x$.

# %%
x = Symbol('x')

x
# Out:
# x

# %% [markdown]
# <h3><b>2. 3 Expressões de uma variável simbólica
#     </b>
# </h3>
#
# &nbsp; Seja <b>x</b> uma variável simbólica. Para representar uma função $f(x)$ em Python, basta atribuir a lei da função a uma variável chamada <b>f</b>.
#
# <center><hr><b>
#
# ```python
# f = lei da função
# ```
#
# </b></center><hr>
#
# <h4>
#     <b>
#         <font color='#008800"'>Exemplo 2</font>
#     </b>
# </h4>
#
# &nbsp; Seja $f$ uma função definida por
# $$ f(x) = x^2-4x-2.$$
# &nbsp; Declare $f$ em Python.

# %%
f = x**2-4*x-2

f
# Out:
# x**2 - 4*x - 2

# %% [markdown]
# <h3><b>2. 4 Valor de uma função em um ponto
#     </b>
# </h3>
# &nbsp; Para determinar o valor de uma função $f(x)$ em um ponto, pode-se utilizar o comando <b>subs</b>. Esse comando substitui a variável simbólica por um valor numérico ou uma expressão simbólica. Se <b>f</b> é uma expressão simbólica que representa a lei da função $f$, para obter o valor de <b>f</b> em um ponto $x = a$ basta escrever:
# <center><hr><b>
#
# ```python
# f.subs(x,a)
# ```
#
# </b></center><hr>
#
# <h4>
#     <b>
#         <font color='#008800"'>Exemplo 3</font>
#     </b>
# </h4>
#
# &nbsp; Utilize a função $f$ declarada no <font color='#008800'><b>Exemplo 2</b></font> e faça o que se pede nos itens a seguir:
#
# <b>a)</b> Calcule o valor de $f(x)$ em $x=1$.

# %% [markdown]
# ![namaonuevo.png](data:image/png;base64,...)

# %%
f.subs(x,1)
# Out:
# -5

# %% [markdown]
# <h3><b>2. 5 Representação gráfica de funções de uma variável
#     </b>
# </h3>
#
# &nbsp; A função <b>plot</b> é utilizada para representar graficamente funções de uma variável. Se <b>f</b> é a lei de uma função expressa em termos de uma variável simbólica <b>x</b>, a representação gráfica no intervalo <b>[a,b]</b> pode ser feita através da linha de comando:
# <center><hr><b>
#
# ```python
# plot(f,(x,a,b))
# ```
#
# </b></center><hr>
#
# <h4>
#     <b>
#         <font color='#008800"'>Exemplo 4</font>
#     </b>
# </h4>
#
# &nbsp; Represente graficamente a função $f(x)$ do <font color='#008800'><b>Exemplo 2</b></font> utilizando o comando <b>plot</b>.

# %%
plot(f,(x,1,100))

# %% [markdown]
# <h2><b>Problema 1: Tesouros no One Piece do Roblox</b>
#
# Em uma ilha no mundo de One Piece do Roblox, a quantidade de "Tesouros" (itens valiosos do jogo) que são encontrados diariamente é estimada pela seguinte função $T(t) = 20 + 5/(t+1)$ onde $T(t)$ representa a quantidade estimada de tesouros encontrados no dia $t$ e $t$ é o número do dia a partir do início de uma grande invasão pirata na ilha ($t = 0$ é o primeiro dia da invasão).

# %% [markdown]
# ![roblox_tesouro.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# <h3>a) Usando Python, calcule a quantidade de tesouros que serão encontrados no 7º dia da invasão (t = 6).

# %% [markdown]
# <h3>b) Calcule a diferença na quantidade de tesouros encontrados entre o 5º dia $(t = 4)$ e o 6º dia $(t = 5)$. Isso representa o aumento ou diminuição na quantidade de tesouros.

# %% [markdown]
# <h3>c) Analise o comportamento da função $T(t)$ à medida que $t $ aumenta indefinidamente (isto é, quando a invasão continua por muito tempo). A quantidade de tesouros encontrados tende a aumentar ou diminuir com o passar do tempo?

# %% [markdown]
# <h3>c) Crie um gráfico em Python que mostre como a quantidade de tesouros varia ao longo dos primeiros $20$ dias da invasão $(t = 0)$ a $(t = 19)$.

# %% [markdown]
# <h2><b>Problema 2: Minecraft e fazenda otimizada</b>
#
# Um fazendeiro no Minecraft tem 100 blocos de cerca para construir um cercado retangular para trigo. Ele fará na frente de um celeiro com 20 blocos de comprimento como um dos lados do cercado.

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# <h3>a) Qual a função que mede a área cercada? Declare $x$ e $y$ no Python e a função da área.

# %% [markdown]
# <h3>b) Esboce o gráfico.

# %% [markdown]
# <h3>c) A partir das coordenadas do vértice, determine a maior área possível de ser cercada. Lembrando que o eixo $y$ desse gráfico é a área em relação ao lado $x$, então $x_v$ será o tamanho do lado $x$ que maximiza a área e $y_v$ a maior área.

# %% [markdown]
# **Coordenadas do Vértice**
#
# A parábola que representa o gráfico de $f(x)=ax^{2}+bx+c$, $a\neq 0$ passa por um ponto $V,$ chamado de vértice, cujas coordenadas são:
#
# $x_{v}=-\frac{b}{2a}$ (abscissa)
#
# $y_{v}=-\frac{\Delta}{4a}$ (ordenada).
#
# Logo, o vértice da parábola é o ponto $V=(-\frac{b}{2a},-\frac{\Delta}{4a}).$
#
# Quando $y$ assume o **maior** valor da função, temos um ponto de máximo. Isso acontece quando $a < 0$, logo o **valor máximo** da função é $y_v$.

# %% [markdown]
# <h3> d) Quais são os valores dos lados $x$ e $y$?
